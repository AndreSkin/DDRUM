# %%
import xml.etree.ElementTree as ET
import csv
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF
from collections import defaultdict
import os
from dotenv import load_dotenv

# %%
def read_tsv(file_tsv):
    with open(file_tsv, 'r', encoding='utf-8') as tsvfile:
        reader = csv.DictReader(tsvfile, delimiter='\t')
        data = defaultdict(lambda: defaultdict(list))
        for row in reader:
            if row['MOA_SOURCE_URL']:
                data[row['DRUG_NAME'].lower()]['MOA'].append(row['MOA_SOURCE_URL'].lower())
            if row['ACT_SOURCE_URL']:
                data[row['DRUG_NAME'].lower()]['ACT'].append(row['ACT_SOURCE_URL'].lower())
        for drug in data:
            if not data[drug]['MOA'] and not data[drug]['ACT']:
                data[drug]['NO_URL'].append('null')
    return data


def generate_rdf_triples(xml_tree, tsv_file):
    data_tsv = read_tsv(tsv_file)

    graph = Graph()
    rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
    ex = Namespace("http://example.org/")
    graph.bind("rdf", rdf)
    graph.bind("ex", ex)
    
    xml_root = xml_tree.getroot()

    study = xml_root
    # brief_title = study.find('./brief_title')
    condition = study.find('./condition')
    intervention_type = study.find('.//intervention_type')
    intervention_name = study.find('.//intervention_name')

    # Check if any of the elements are None
    if None in [condition, intervention_type, intervention_name]:
        return None  # Return None to indicate that the file should be skipped

    condition = condition.text
    intervention_type = intervention_type.text.lower()
    intervention_name = intervention_name.text.lower()  # Convert to lowercase
    # print([condition, intervention_type, intervention_name])

    if intervention_type == 'drug' and intervention_name in data_tsv:
        urls = data_tsv[intervention_name]

        # Add triples to graph
        subject = ex[intervention_name.replace(" ", "_")]  # Valid URIs
        graph.add((subject, RDF.type, ex['Drug']))
        graph.add((subject, ex['condition'], Literal(condition)))
        graph.add((subject, ex['intervention_name'], Literal(intervention_name)))
        
        for url_type in urls:
            for url in urls[url_type]:
                graph.add((subject, ex[url_type], URIRef(url)))
    else:
        return None

    return graph

# %%
# Load the environment variables from the .env file
load_dotenv()

folder = os.getenv('FOLDER')
tsv_file = os.getenv('FILE_TSV')


graphs = []

# Iterate over all files in the directory and its subdirectories
for dirpath, dirnames, filenames in os.walk(folder):
    for filename in filenames:
        if filename.endswith('.xml'):
            file_xml = os.path.join(dirpath, filename)
            tree = ET.parse(file_xml)
            graph = generate_rdf_triples(tree, tsv_file)
            if graph is not None:  # Only add the graph to the list if the file was not skipped
                graphs.append(graph)

for graph in graphs:
    json_ld_data = graph.serialize(format='json-ld', indent=4)
    print(json_ld_data)
# Out:
# [
#     {
#         "@id": "http://example.org/paclitaxel",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/11309480"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/11309480"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Primary Peritoneal Carcinoma"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "paclitaxel"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/docetaxel",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl3545252"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Breast Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "docetaxel"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/paclitaxel",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/11309480"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/11309480"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Vulvar Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "paclitaxel"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org

#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "McCune Albright Syndrome"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "pegvisomant"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/rifabutin",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl444633"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Tuberculosis"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "rifabutin"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/ondansetron",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl46"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Schizophrenia"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "ondansetron"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/guanfacine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "http://www.accessdata.fda.gov/drugsatfda_docs/label/2015/022037s011lbl.pdf"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Post-Traumatic Stress Disorder"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "guanfacine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/docetaxel",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl3545252"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Breast Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "docetaxel"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/bortezomib",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl325041"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Squamous Cell Carcinoma"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "bortezomib"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/lamivudine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl141"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "HIV Infections"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "lamivudine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/pioglitazone",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl595"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Fatty Liver"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "pioglitazone"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/methylphenidate",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl796"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Attention Deficit Disorder With Hyperactivity"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "methylphenidate"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/thalidomide",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/25043012"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/26131937"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Colorectal Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "thalidomide"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/quetiapine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl3188993"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Schizophrenia"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "quetiapine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/propranolol",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "http://www.accessdata.fda.gov/drugsatfda_docs/label/2008/016419s029lbl.pdf"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Seasonal Affective Disorder"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "propranolol"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/methylphenidate",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl796"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Cocaine-Related Disorders"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "methylphenidate"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/capecitabine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl1773"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "capecitabine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/fluoxetine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl41"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Domestic Violence"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "fluoxetine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/floxuridine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl917"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Recurrent Colon Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "floxuridine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/olanzapine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl715"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Alzheimer's Disease"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "olanzapine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/ixabepilone",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/19010832"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/19010832"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Prostate Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "ixabepilone"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/ixabepilone",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/19010832"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/19010832"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Esophageal Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "ixabepilone"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/thalidomide",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/25043012"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/26131937"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Sarcoma"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "thalidomide"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/atazanavir",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl1163"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "HIV Infections"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "atazanavir"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/fluorouracil",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl185"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Pancreatic Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "fluorouracil"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/arsenic_trioxide",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl1200978"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Multiple Myeloma and Plasma Cell Neoplasm"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "arsenic trioxide"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/nortriptyline",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/17071817"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl445"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Smoking"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "nortriptyline"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/paroxetine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl1200609"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Depression"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "paroxetine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/thalidomide",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/25043012"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/26131937"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Chronic Myelomonocytic Leukemia"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "thalidomide"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/ribavirin",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl1643"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Infection"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "ribavirin"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/ixabepilone",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/ACT": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/19010832"
#             }
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://pubmed.ncbi.nlm.nih.gov/19010832"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Pancreatic Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "ixabepilone"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/desipramine",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl72"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Back Pain"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "desipramine"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/rosiglitazone",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl121"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Alzheimer Disease"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "rosiglitazone"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/bicalutamide",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl409"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Fallopian Tube Cancer"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "bicalutamide"
#             }
#         ]
#     }
# ]
# [
#     {
#         "@id": "http://example.org/methylphenidate",
#         "@type": [
#             "http://example.org/Drug"
#         ],
#         "http://example.org/MOA": [
#             {
#                 "@id": "https://www.ebi.ac.uk/chembl/compound/inspect/chembl796"
#             }
#         ],
#         "http://example.org/condition": [
#             {
#                 "@value": "Attention Deficit Hyperactivity Disorder"
#             }
#         ],
#         "http://example.org/intervention_name": [
#             {
#                 "@value": "methylphenidate"
#             }
#         ]
#     }
# ]
