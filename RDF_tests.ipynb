# %%
import os
import csv
import json
from rdflib import Graph, Namespace, URIRef, Literal
import urllib.parse

from dotenv import load_dotenv

# %%
def read_tsv_file(tsv_file):
    drugs = {}
    with open(tsv_file, 'r') as tsv:
        reader = csv.DictReader(tsv, delimiter='\t')
        for row in reader:
            drug_name = row['DRUG_NAME'].lower()
            moa_urls = row.get('MOA_SOURCE_URL', '').split(';')
            act_urls = row.get('ACT_SOURCE_URL', '').split(';')
            drugs[drug_name] = {'MOA': moa_urls if moa_urls != [''] else [], 'ACT': act_urls if act_urls != [''] else []}
    return drugs

# %%
def traverse_folder(folder):
    xml_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.xml'):
                xml_files.append(os.path.join(root, file))
    return xml_files

# %%
import xml.etree.ElementTree as ET

def parse_xml(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Initialize variables
    disease = None
    intervention_type = None
    intervention_name = None
    study_url = None

    # Extract information from the XML file
    try:
        required_header = root.find(".//required_header")
        url = required_header.findtext("url")

        condition = root.find(".//condition")
        if condition is not None:
            disease = condition.text.lower()

        intervention_type_elem = root.find(".//intervention_type")
        if intervention_type_elem is not None:
            intervention_type = intervention_type_elem.text.lower()

        if intervention_type == 'drug':
            intervention_name_elem = root.find(".//intervention_name")
            if intervention_name_elem is not None:
                intervention_name = intervention_name_elem.text.lower()
            study_url = url
    except Exception as e:
        print(f"Error parsing XML file {xml_file}: {e}")
        return None

    return {
        'disease': disease,
        'intervention_type': intervention_type,
        'intervention_name': intervention_name,
        'study_url': study_url
    }

# %%
def create_rdf_graph(drugs, xml_files):
    RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
    DCT = Namespace("http://purl.org/dc/terms/")
    # Create an RDF Graph
    graph = Graph()

    for drug, urls in drugs.items():
        drug_node = URIRef(f"drug:{urllib.parse.quote(drug)}")
        for url in urls['MOA']:
            graph.add((drug_node, DCT.source, URIRef(urllib.parse.quote(url))))
        for url in urls['ACT']:
            graph.add((drug_node, DCT.hasPart, URIRef(urllib.parse.quote(url))))

    for xml_file in xml_files:
        data = parse_xml(xml_file)
        if data is None:
            continue
        
        disease = data['disease']
        intervention_type = data['intervention_type']
        intervention_name = data['intervention_name']
        study_url = data['study_url']

        if intervention_type is None or intervention_type.lower() != 'drug':
            continue

        if None in [disease, intervention_name, study_url]:
            continue

        disease_node = URIRef(f"disease:{urllib.parse.quote(disease)}")
        study_node = URIRef(f"study:{urllib.parse.quote(study_url)}")

        graph.add((study_node, DCT.subject, disease_node))
        graph.add((study_node, DCT.relation, URIRef(urllib.parse.quote(intervention_name))))
        graph.add((disease_node, RDF.type, DCT.subject))
        graph.add((disease_node, DCT.relation, URIRef(urllib.parse.quote(intervention_name))))
    
    return graph

# %%
def serialize_rdf_to_json_ld(graph):
    return graph.serialize(format='json-ld', indent=4)

# %%
load_dotenv()
tsv_file = os.getenv('FILE_TSV')
folder = os.getenv('TEST_FILES')

drugs = read_tsv_file(tsv_file)
xml_files = traverse_folder(folder)
rdf_graph = create_rdf_graph(drugs, xml_files)
json_ld = serialize_rdf_to_json_ld(rdf_graph)

print(json_ld)
# Out:
# [
#     {
#         "@id": "drug:lofexidine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20040696"
#             }
#         ]
#     },
#     {
#         "@id": "drug:acipimox",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17705685"
#             }
#         ]
#     },
#     {
#         "@id": "disease:metabolism%2C%20inborn%20errors",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "cyclosporine"
#             }
#         ]
#     },
#     {
#         "@id": "drug:etelcalcetide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.ema.europa.eu/docs/en_GB/document_library/EPAR_-_Product_Information/human/003995/WC500217100.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010816",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "herbal%20remedies"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:hepatitis%20c"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nafarelin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201309"
#             }
#         ]
#     },
#     {
#         "@id": "drug:gabapentin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/21651903"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/21651903"
#             }
#         ]
#     },
#     {
#         "@id": "drug:eluxadoline",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/22671931"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/206940s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:diethylpropion",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1194666"
#             }
#         ]
#     },
#     {
#         "@id": "drug:gilteritinib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/27908881"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/211349s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:trifarotene",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/29706423"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/29706423"
#             }
#         ]
#     },
#     {
#         "@id": "drug:macimorelin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/12240910"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2017/205598s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:mosapride",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/8950316"
#             }
#         ]
#     },
#     {
#         "@id": "drug:urapidil",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.kegg.jp/entry/D01333"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00012454",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "e-selectin%20nasal%20spray"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:cerebrovascular%20accident"
#             }
#         ]
#     },
#     {
#         "@id": "drug:halothane",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL931"
#             }
#         ]
#     },
#     {
#         "@id": "drug:safinamide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17915852"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17030736"
#             }
#         ]
#     },
#     {
#         "@id": "drug:avelumab",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2017/761049s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:carfilzomib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17616698"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17616698"
#             }
#         ]
#     },
#     {
#         "@id": "drug:conjugated%20estrogens",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2003/21396_prempro_lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:piperacillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL702"
#             }
#         ]
#     },
#     {
#         "@id": "drug:eflornithine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/3924048"
#             }
#         ]
#     },
#     {
#         "@id": "drug:dexbrompheniramine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201287"
#             }
#         ]
#     },
#     {
#         "@id": "drug:crofelemer",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2012/202292s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nalidixic%20acid",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL5"
#             }
#         ]
#     },
#     {
#         "@id": "drug:azlocillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1537"
#             }
#         ]
#     },
#     {
#         "@id": "drug:meprobamate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL979"
#             }
#         ]
#     },
#     {
#         "@id": "drug:metyrapone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2013/012911Orig1s033lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:iproniazid",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/1101049"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nicotinic%20acid",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17705685"
#             }
#         ]
#     },
#     {
#         "@id": "drug:travoprost",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/10454045"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/10454045"
#             }
#         ]
#     },
#     {
#         "@id": "drug:acetylmethadol",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19153939"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.kegg.jp/entry/D04973"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00012337",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "gefitinib"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:kidney%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00011960",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "cisplatin"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:esophageal%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "drug:isoetarine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201213"
#             }
#         ]
#     },
#     {
#         "@id": "drug:desmopressin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/9792651"
#             }
#         ]
#     },
#     {
#         "@id": "drug:glycopyrronium%20bromide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.ema.europa.eu/docs/en_GB/document_library/EPAR_-_Public_assessment_report/human/002430/WC500133771.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.guidetopharmacology.org/GRAC/LigandDisplayForward%3FligandId%3D7459"
#             }
#         ]
#     },
#     {
#         "@id": "drug:mephenytoin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL861"
#             }
#         ]
#     },
#     {
#         "@id": "drug:fosaprepitant",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1199324"
#             }
#         ]
#     },
#     {
#         "@id": "disease:dementia",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "ginkgo%20biloba%20extract"
#             },
#             {
#                 "@id": "ginkgo%20biloba"
#             },
#             {
#                 "@id": "acetaminophen%20650%20mg%20qid%20and%20placebo%20qid%20prn.%20the%20other%20arm%20was%20placebo%20qid%20and%20acetaminophen%20650%20mg%20qid%20prn"
#             }
#         ]
#     },
#     {
#         "@id": "drug:icotinib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/22959248"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/22088449"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tezacaftor",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/210491lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:azasetron",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19967488"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19967488"
#             }
#         ]
#     },
#     {
#         "@id": "drug:omidenepag%20isopropyl",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/30465134"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/30465134"
#             }
#         ]
#     },
#     {
#         "@id": "drug:copanlisib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24170767"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2017/209936s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:abciximab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2013/103575s5126lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2013/103575s5126lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:frovatriptan",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1279"
#             }
#         ]
#     },
#     {
#         "@id": "drug:triamterene",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL585"
#             }
#         ]
#     },
#     {
#         "@id": "drug:fluoroestradiol%20f%2018",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/212155s000lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/212155s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:cefazolin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1435"
#             }
#         ]
#     },
#     {
#         "@id": "drug:albiglutide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/15331566"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/125431s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:metipranolol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1291"
#             }
#         ]
#     },
#     {
#         "@id": "drug:evocalcet",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/29724589"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/29724589"
#             }
#         ]
#     },
#     {
#         "@id": "drug:meptazinol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/6141283"
#             }
#         ]
#     },
#     {
#         "@id": "drug:alclometasone%20dipropionate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200989"
#             }
#         ]
#     },
#     {
#         "@id": "drug:landiolol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.kegg.jp/entry/D01847"
#             }
#         ]
#     },
#     {
#         "@id": "drug:lemborexant",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/212028s000lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/212028s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:mivacurium",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL984"
#             }
#         ]
#     },
#     {
#         "@id": "drug:arformoterol",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/12090787"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/021912s013lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:dotinurad",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/31371478"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/33062187"
#             }
#         ]
#     },
#     {
#         "@id": "drug:aceprometazine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.has-sante.fr/portail/upload/docs/application/pdf/2012-09/mepronizine_ct_8952.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00012012",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "amifostine%20trihydrate"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:cervical%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "drug:lypressin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200690"
#             }
#         ]
#     },
#     {
#         "@id": "drug:levomilnacipran",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/23499664"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/23499664"
#             }
#         ]
#     },
#     {
#         "@id": "drug:glasdegib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24900436"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/210656s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00012142",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "temsirolimus"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:prostate%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "drug:fosnetupitant",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/16332435"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/210493s000lbl.pdf/drugsatfda_docs/label/2014/125477s007lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:amcinonide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200732"
#             }
#         ]
#     },
#     {
#         "@id": "drug:peginesatide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2012/202799s001lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nepinalone",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/22711801"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00012363",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "gemcitabine%20hydrochloride"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:esophageal%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "drug:rucaparib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//dx.doi.org/10.1021/acs.jmedchem.6b00990"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2016/209115s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010907",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "npi-028"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:alcoholism"
#             }
#         ]
#     },
#     {
#         "@id": "disease:diamond%20blackfan%20anemia",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "g-csf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00011973",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "fenretinide"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:kidney%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "disease:lymphatic%20malformations",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "picibanil"
#             }
#         ]
#     },
#     {
#         "@id": "drug:docosanol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200453"
#             }
#         ]
#     },
#     {
#         "@id": "drug:lesinurad",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/207988lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/207988lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:avobenzone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200522"
#             }
#         ]
#     },
#     {
#         "@id": "drug:lutetium%20%28177lu%29%20oxodotreotide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/208700s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:oxacillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL819"
#             }
#         ]
#     },
#     {
#         "@id": "drug:luspatercept",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24658078"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/761136lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "disease:periodontitis",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "connective%20tissue%20nutrient%20formula"
#             }
#         ]
#     },
#     {
#         "@id": "disease:osteoporosis",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "dietary%20phytoestrogens"
#             },
#             {
#                 "@id": "alendronate"
#             }
#         ]
#     },
#     {
#         "@id": "drug:sulfamethizole",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1191"
#             }
#         ]
#     },
#     {
#         "@id": "drug:pinacidil",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1159"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010803",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "ginkgo%20biloba"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:dementia"
#             }
#         ]
#     },
#     {
#         "@id": "drug:quingestanol%20acetate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.kegg.jp/entry/D05679"
#             }
#         ]
#     },
#     {
#         "@id": "drug:botulinum%20toxin%20type%20a",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/8103915"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nifedipine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17276408"
#             }
#         ]
#     },
#     {
#         "@id": "drug:vernakalant",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17872968"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17872968"
#             }
#         ]
#     },
#     {
#         "@id": "drug:radotinib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/25676420"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/25676420"
#             }
#         ]
#     },
#     {
#         "@id": "drug:betrixaban",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19297154"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2017/208383s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:telbivudine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/22139434"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2013/022011s013lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nintedanib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19522465"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19522465"
#             }
#         ]
#     },
#     {
#         "@id": "drug:metaraminol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201319"
#             }
#         ]
#     },
#     {
#         "@id": "drug:volanesorsen",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ema.europa.eu/en/documents/assessment-report/waylivra-epar-public-assessment-report_en.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010725",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "mak"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:cardiovascular%20diseases"
#             }
#         ]
#     },
#     {
#         "@id": "drug:ibrutinib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17154430"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17154430"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tulobuterol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/15212190"
#             }
#         ]
#     },
#     {
#         "@id": "drug:flopropione",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//eisai.jp/medical/products/di/EPI/CSP_C_EPI.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//eisai.jp/medical/products/di/EPI/CSP_C_EPI.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:piribedil",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20600305"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tesamorelin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2013/022505s004lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2013/022505s004lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:dacomitinib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/30506139"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/211288s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "disease:thymoma",
#         "@type": [
#             "http://purl.org/dc/terms/subject"
#         ],
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "carboplatin"
#             }
#         ]
#     },
#     {
#         "@id": "drug:cefotetan",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL474579"
#             }
#         ]
#     },
#     {
#         "@id": "drug:alogliptin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL376359"
#             }
#         ]
#     },
#     {
#         "@id": "drug:alprazolam",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL661"
#             }
#         ]
#     },
#     {
#         "@id": "drug:romiplostim",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/125268s141lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/125268s141lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tenofovir%20disoproxil",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1538"
#             }
#         ]
#     },
#     {
#         "@id": "drug:diphemanil",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201340"
#             }
#         ]
#     },
#     {
#         "@id": "drug:omalizumab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/103976s5161lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/103976s5161lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:phenoxymethylpenicillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL615"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tyramine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/21073468"
#             }
#         ]
#     },
#     {
#         "@id": "drug:secukinumab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/23253932"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/23253932"
#             }
#         ]
#     },
#     {
#         "@id": "drug:prabotulinumtoxina",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/761085s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:mirabegron",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17293563"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17293563"
#             }
#         ]
#     },
#     {
#         "@id": "drug:angiotensin%20ii",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2017/209360s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:ketamine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/27144355"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/27144355"
#             }
#         ]
#     },
#     {
#         "@id": "drug:latamoxef",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL74632"
#             }
#         ]
#     },
#     {
#         "@id": "drug:sulfalene",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1525826"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00012857",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "acetaminophen%20650%20mg%20qid%20and%20placebo%20qid%20prn.%20the%20other%20arm%20was%20placebo%20qid%20and%20acetaminophen%20650%20mg%20qid%20prn"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:dementia"
#             }
#         ]
#     },
#     {
#         "@id": "drug:moexipril",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1165"
#             }
#         ]
#     },
#     {
#         "@id": "drug:opicapone",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24847974"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24847974"
#             }
#         ]
#     },
#     {
#         "@id": "drug:blonanserin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/15686911"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/15686911"
#             }
#         ]
#     },
#     {
#         "@id": "drug:moxifloxacin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL32"
#             }
#         ]
#     },
#     {
#         "@id": "drug:triamcinolone%20diacetate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200449"
#             }
#         ]
#     },
#     {
#         "@id": "drug:setmelanotide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/nda/2020/213793Orig1s000ClinPharmR.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/213793Orig1s000RPLlbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:esomeprazole",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201320"
#             }
#         ]
#     },
#     {
#         "@id": "drug:phenazone",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/25765567"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/25765567"
#             }
#         ]
#     },
#     {
#         "@id": "drug:agomelatine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.ema.europa.eu/docs/en_GB/document_library/EPAR_-_Product_Information/human/000916/WC500038317.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:procainamide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL605"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010010",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "exemestane"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:breast%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "drug:carbetocin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/15740719"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebs.tga.gov.au/ebs/picmi/picmirepository.nsf/pdf%3FOpenAgent%26id%3DCP-2015-PI-01665-1"
#             }
#         ]
#     },
#     {
#         "@id": "drug:sotorasib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2021/214665s000lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2021/214665s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:calcitonin%20%28salmon%20synthetic%29",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/14623894"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/017808s036lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:pralidoxime",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1420"
#             }
#         ]
#     },
#     {
#         "@id": "drug:finasteride",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/020788s024lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:daclatasvir",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20410884"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20410884"
#             }
#         ]
#     },
#     {
#         "@id": "drug:drospirenone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1509"
#             }
#         ]
#     },
#     {
#         "@id": "drug:belantamab%20mafodotin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/32936437"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/761158s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:paramethadione",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1100"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tafamidis",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.ema.europa.eu/docs/en_GB/document_library/EPAR_-_Product_Information/human/002294/WC500117862.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.ema.europa.eu/docs/en_GB/document_library/EPAR_-_Product_Information/human/002294/WC500117862.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:borofalan%20%2810b%29",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.pmda.go.jp/files/000237990.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:celiprolol",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/9205952"
#             }
#         ]
#     },
#     {
#         "@id": "drug:barnidipine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.kegg.jp/entry/D07494"
#             }
#         ]
#     },
#     {
#         "@id": "drug:denopamine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/12487507"
#             }
#         ]
#     },
#     {
#         "@id": "drug:dexamethasone%20acetate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1651"
#             }
#         ]
#     },
#     {
#         "@id": "drug:cloxacillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL891"
#             }
#         ]
#     },
#     {
#         "@id": "drug:benzocaine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19661462"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/12173241"
#             }
#         ]
#     },
#     {
#         "@id": "drug:nivolumab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24872026"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24872026"
#             }
#         ]
#     },
#     {
#         "@id": "drug:loteprednol%20etabonate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200865"
#             }
#         ]
#     },
#     {
#         "@id": "drug:darolutamide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/26137992"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/212099Orig1s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:imdevimab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.fda.gov/media/145611/download"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.fda.gov/media/145611/download"
#             }
#         ]
#     },
#     {
#         "@id": "drug:sargramostim",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/2001448"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/2001448"
#             }
#         ]
#     },
#     {
#         "@id": "drug:glipizide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/2445740"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/2445740"
#             }
#         ]
#     },
#     {
#         "@id": "drug:zopiclone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/021476s030lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:moracizine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1075"
#             }
#         ]
#     },
#     {
#         "@id": "drug:lubiprostone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201134"
#             }
#         ]
#     },
#     {
#         "@id": "drug:forodesine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/9628722"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17897085"
#             }
#         ]
#     },
#     {
#         "@id": "drug:pyrazinamide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL614"
#             }
#         ]
#     },
#     {
#         "@id": "drug:teprotumumab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20847162"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/761143s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:acetohexamide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/10742287"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/10742287"
#             }
#         ]
#     },
#     {
#         "@id": "drug:testolactone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1571"
#             }
#         ]
#     },
#     {
#         "@id": "drug:phenprocoumon",
#         "http://purl.org/dc/terms/hasPart": [
#             {
# ...
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1744"
#             }
#         ]
#     },
#     {
#         "@id": "drug:carbenicillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1214"
#             }
#         ]
#     },
#     {
#         "@id": "drug:bulevirtide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.ema.europa.eu/en/documents/assessment-report/hepcludex-epar-public-assessment-report_en.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ema.europa.eu/en/documents/product-information/hepcludex-epar-product-information_en.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:anidulafungin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL264241"
#             }
#         ]
#     },
#     {
#         "@id": "drug:ombitasvir",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24400777"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/206619s003lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:setastine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/1982751"
#             }
#         ]
#     },
#     {
#         "@id": "drug:rescinnamine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1668"
#             }
#         ]
#     },
#     {
#         "@id": "drug:etanercept",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/103795s5548lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/103795s5548lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:dexrabeprazole",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/2154989"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/2154989"
#             }
#         ]
#     },
#     {
#         "@id": "drug:tenapanor",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/28495802"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/211801s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:alpelisib",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/31256368"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/212526s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010361",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "cyclosporine"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:metabolism%2C%20inborn%20errors"
#             }
#         ]
#     },
#     {
#         "@id": "study:https%3A//clinicaltrials.gov/ct2/show/NCT00010322",
#         "http://purl.org/dc/terms/relation": [
#             {
#                 "@id": "atamestane"
#             }
#         ],
#         "http://purl.org/dc/terms/subject": [
#             {
#                 "@id": "disease:breast%20cancer"
#             }
#         ]
#     },
#     {
#         "@id": "drug:paliperidone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/021999s029lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:ceruletide",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201355"
#             }
#         ]
#     },
#     {
#         "@id": "drug:ilaprazole",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/11304936"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/11304936"
#             }
#         ]
#     },
#     {
#         "@id": "drug:rimonabant",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.ema.europa.eu/docs/en_GB/document_library/EPAR_-_Product_Information/human/000666/WC500021287.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:sparfloxacin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL850"
#             }
#         ]
#     },
#     {
#         "@id": "drug:insulin%20glargine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/021081s062lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/021081s062lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:paclitaxel",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/11309480"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/11309480"
#             }
#         ]
#     },
#     {
#         "@id": "drug:mirodenafil",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//dx.doi.org/10.1002/jlcr.1116"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/18638004"
#             }
#         ]
#     },
#     {
#         "@id": "drug:gemtuzumab%20ozogamicin",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2006/021174s020lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2006/021174s020lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:basiliximab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2001/basnova032301LB.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2001/basnova032301LB.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:flunarizine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/19582593"
#             }
#         ]
#     },
#     {
#         "@id": "drug:calcipotriene",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200666"
#             }
#         ]
#     },
#     {
#         "@id": "drug:bretylium",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1199080"
#             }
#         ]
#     },
#     {
#         "@id": "drug:lithium%20carbonate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200826"
#             }
#         ]
#     },
#     {
#         "@id": "drug:cyclacillin",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200356"
#             }
#         ]
#     },
#     {
#         "@id": "drug:mebendazole",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL685"
#             }
#         ]
#     },
#     {
#         "@id": "drug:inqovi",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/24520856"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/212576s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:crisaborole",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20188549"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2016/207695s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:ansuvimab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/761172s000lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2020/761172s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:galcanezumab",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2018/761063s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:vorapaxar",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/18447380"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/18447380"
#             }
#         ]
#     },
#     {
#         "@id": "drug:luliconazole",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL2105689"
#             }
#         ]
#     },
#     {
#         "@id": "drug:rimexolone",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1200617"
#             }
#         ]
#     },
#     {
#         "@id": "drug:halopredone%20acetate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.kegg.jp/entry/D01743"
#             }
#         ]
#     },
#     {
#         "@id": "drug:linaclotide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20863829"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/20863829"
#             }
#         ]
#     },
#     {
#         "@id": "drug:methysergide",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/15322733"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.guidetopharmacology.org/GRAC/LigandDisplayForward%3FligandId%3D134"
#             }
#         ]
#     },
#     {
#         "@id": "drug:alemtuzumab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/103948s5139lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2014/103948s5139lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:dupilumab",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2017/761055lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:echothiophate",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1201341"
#             }
#         ]
#     },
#     {
#         "@id": "drug:levosimendan",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/18570382"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/18570382"
#             }
#         ]
#     },
#     {
#         "@id": "drug:emedastine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2003/20706slr011_emadine_lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2003/20706slr011_emadine_lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:valaciclovir",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1349"
#             }
#         ]
#     },
#     {
#         "@id": "drug:valganciclovir",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL252321"
#             }
#         ]
#     },
#     {
#         "@id": "drug:solriamfetol",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2019/211230s000lbl.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:clascoterone",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//www.accessdata.fda.gov/drugsatfda_docs/nda/2020/213433Orig1s000MultidisciplineR.pdf"
#             }
#         ]
#     },
#     {
#         "@id": "drug:bepridil",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/1281221"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/1281221"
#             }
#         ]
#     },
#     {
#         "@id": "drug:levamlodipine",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17213004"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//pubmed.ncbi.nlm.nih.gov/17213004"
#             }
#         ]
#     },
#     {
#         "@id": "drug:efinaconazole",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL2103877"
#             }
#         ]
#     },
#     {
#         "@id": "drug:doxylamine",
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "https%3A//www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1004"
#             }
#         ]
#     },
#     {
#         "@id": "drug:panitumumab",
#         "http://purl.org/dc/terms/hasPart": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/125147s200lbl.pdf"
#             }
#         ],
#         "http://purl.org/dc/terms/source": [
#             {
#                 "@id": "http%3A//www.accessdata.fda.gov/drugsatfda_docs/label/2015/125147s200lbl.pdf"
#             }
#         ]
#     }
# ]
